# %% [markdown]
# 1. What is a random variable in probability theory?
# -  In probability theory, a random variable is a function that assigns a numerical value to each possible outcome of a random experiment.
#
#  In simpler words:
# A random variable is a way to represent uncertain outcomes with numbers.
#
# Types of Random Variables:
#
# - Discrete Random Variable
#
# Takes on a finite or countable number of values.
#
# Example: Number of heads when tossing 3 coins (values = 0, 1, 2, 3).
#
# - Continuous Random Variable
#
# Takes on infinitely many values within an interval (uncountable).
#
# Example: The time taken for a train to arrive (values can be 5.2 min, 5.23 min, etc.).
#
# 2. What are the types of random variables?
# -
# 1. Discrete Random Variable
#
# Can take on finite or countably infinite values (you can list them one by one).
#
# Usually represents outcomes that are counts.
#
# Examples:
#
# Tossing a coin →
# 𝑋
# =
# X= {0 for tails, 1 for heads}.
#
# Rolling a die →
# 𝑋
# =
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# X={1,2,3,4,5,6}.
#
# Number of calls received in an hour.
#
# 2. Continuous Random Variable
#
# Can take on uncountably infinite values, typically over an interval of real numbers.
#
# Represents measurements that can vary continuously.
#
# Examples:
#
# Height or weight of a person.
#
# Time taken to finish a task.
#
# Temperature in a city.
#
# 3. Mixed Random Variables (less common, advanced)
#
# Some variables are a mixture of discrete and continuous parts.
#
# Example:
#
# Insurance claims: with probability 0.7 the claim is ₹0 (discrete), otherwise it is a continuous amount between ₹1 and ₹50,000.
#
# 3. Explain the difference between discrete and continuous distributions.
# -
# 1. Discrete Distribution Deals with discrete random variables (countable outcomes).
# Probability is assigned to individual values.
#
# Represented by Probability Mass Function (PMF).
#
# Example: Binomial distribution (number of heads in 5 coin tosses).
#
# 2. Continuous Distribution Deals with continuous random variables (uncountable outcomes).
# Probability of any single exact value is zero; probabilities are assigned over intervals.
#
# Represented by Probability Density Function (PDF).
#
# Example: Normal distribution (heights of people, exam scores).
#
# 4. What is a binomial distribution, and how is it used in probability?
#
# - A binomial distribution is a type of probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure.
# Key Characteristics: Fixed number of trials (n).
#
# Each trial has only two outcomes (success/failure).
#
# Probability of success (p) remains constant in every trial.
#
# Trials are independent of each other.
#
# Probability Formula:
#
# N = number of trials
#
# K = number of successes
#
# P = probability of success
#
# 1−p1-p1−p = probability of failure
#
# 5.  What is the standard normal distribution, and why is it important?
#
# - The standard normal distribution is a special case of the normal distribution where: The mean (μ) = 0
# The standard deviation (σ) = 1
#
# It is bell-shaped and symmetric about the mean.
#
# The variable that follows this distribution is called the standard normal variable (Z), and values are often referred to as z-scores.
#
# Why it is important? Simplifies calculations – Any normal distribution can be converted into the standard normal using
#
# Widely used in statistics – for hypothesis testing, confidence intervals, and control charts.
#
# Probability tables (Z-tables) – provide cumulative probabilities for the standard normal, making it easy to find probabilities for any normal distribution.
#
# Foundation for inferential statistics – many statistical methods assume normality.
#
# 6. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - Definition of CLT:
#
# The Central Limit Theorem states that:
#
# If we take a large number of independent random samples from a population (with any distribution, but with finite mean
# 𝜇
# μ and variance
# 𝜎
# 2
# σ
# 2
# ), then the sampling distribution of the sample mean will approximately follow a normal distribution with
#
# Mean
# =
# 𝜇
# ,
# Variance
# =
# 𝜎
# 2
# 𝑛
# Mean=μ,Variance=
# n
# σ
# 2
# 	​
#
#
# as the sample size
# 𝑛
# n becomes large.
#
# Why it is Critical? Foundation of Inferential Statistics – It allows us to use the normal distribution to make conclusions about population means, even if the population itself is not normal.
#
# Practical Use – With large enough sample sizes (usually n≥30n \geq 30n≥30), the sample mean behaves like a normal variable.
#
# Supports Confidence Intervals & Hypothesis Testing – Enables calculation of probabilities and critical values.
#
# Universal Applicability – Works for many types of data (finance, manufacturing, surveys, etc.).
#
# 7.  What is the significance of confidence intervals in statistical analysis?
#
# - A confidence interval (CI) is a range of values, calculated from sample data, that is likely to contain the true population parameter (like mean or proportion) with a certain level of confidence.
# Significance of Confidence Intervals Provides an Estimate with Precision
#
# Instead of giving just a single point estimate (e.g., sample mean = 50), a CI gives a range (e.g., 47 to 53) showing the possible values of the population parameter.
#
# Accounts for Sampling Error
#
# Acknowledges uncertainty in sample data and adjusts for variability.
#
# Connects to Probability
#
# A 95% CI means: if we repeatedly take samples and build CIs, about 95% of them will capture the true population parameter.
#
# Supports Decision-Making
#
# Widely used in research, business, and quality control to judge reliability of results.
#
# 8. What is the concept of expected value in a probability distribution?
#
# - The expected value (EV) of a probability distribution is the long-run average or mean value of a random variable if an experiment is repeated many times. It represents the “center of gravity” of the distribution. For a random variable XXX: Discrete case:
# Continuous case:
#
# Interpretation: It is the weighted average of all possible values of the random variable, with probabilities as weights.
#
# Example: If a dice is rolled,
#
# Even though 3.5 is not a possible outcome, it’s the average over the long run.

# %%
#9 : Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate 1000 random numbers from Normal Distribution (mean=50, std=5)
data = np.random.normal(loc=50, scale=5, size=1000)

# Step 2: Compute mean and standard deviation
mean_val = np.mean(data)
std_val = np.std(data)

print("Computed Mean:", mean_val)
print("Computed Standard Deviation:", std_val)

# Step 3: Plot histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.title("Histogram of Normally Distributed Data (μ=50, σ=5)")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Computed Mean: 49.79295458300308
# Computed Standard Deviation: 4.843314796373163

# %%
#10  You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
# 235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
# ● Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
# ● Write the Python code to compute the mean sales and its confidence interval.

import numpy as np
import scipy.stats as stats

# Given sales data
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

# Convert to NumPy array
data = np.array(daily_sales)

# Sample size, mean, and standard deviation
n = len(data)
mean_val = np.mean(data)
std_val = np.std(data, ddof=1)   # use sample standard deviation (ddof=1)

# Standard error of the mean
sem = std_val / np.sqrt(n)

# 95% confidence interval using t-distribution (better for small n)
confidence = 0.95
t_score = stats.t.ppf((1 + confidence) / 2, df=n-1)
margin_of_error = t_score * sem

ci_lower = mean_val - margin_of_error
ci_upper = mean_val + margin_of_error

print("Sample Mean Sales:", mean_val)
print("95% Confidence Interval: ({:.2f}, {:.2f})".format(ci_lower, ci_upper))
# Out:
# Sample Mean Sales: 248.25
# 95% Confidence Interval: (240.17, 256.33)
